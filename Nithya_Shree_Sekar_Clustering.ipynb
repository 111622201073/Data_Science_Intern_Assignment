# %%
import pandas as pd
customer=pd.read_csv('Customers.csv')
print(customer.head(10))
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15
# 5      C0006     Brittany Palmer  South America  2024-01-07
# 6      C0007         Paul Graves           Asia  2022-06-18
# 7      C0008            David Li  North America  2024-01-13
# 8      C0009           Joy Clark         Europe  2023-08-14
# 9      C0010           Aaron Cox         Europe  2022-12-15

# %%
product=pd.read_csv('Products.csv')
product.head(10)
# Out:
#   ProductID                  ProductName     Category   Price
# 0      P001         ActiveWear Biography        Books  169.30
# 1      P002        ActiveWear Smartwatch  Electronics  346.30
# 2      P003      ComfortLiving Biography        Books   44.12
# 3      P004                BookWorld Rug   Home Decor   95.69
# 4      P005              TechPro T-Shirt     Clothing  429.31
# 5      P006               ActiveWear Rug   Home Decor  121.32
# 6      P007           SoundWave Cookbook        Books  420.15
# 7      P008  BookWorld Bluetooth Speaker  Electronics  146.85
# 8      P009           BookWorld Wall Art   Home Decor  325.01
# 9      P010     ComfortLiving Smartwatch  Electronics  350.13

# %%
transaction=pd.read_csv('Transactions.csv')
transaction.head(10)
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
# 5        T00442      C0188      P067  2024-12-26 14:40:03         1
# 6        T00490      C0195      P067  2024-11-24 11:49:48         3
# 7        T00536      C0008      P067  2024-09-22 06:13:59         1
# 8        T00564      C0157      P067  2024-12-07 17:57:40         3
# 9        T00631      C0130      P067  2024-05-14 23:14:59         2
#
#    TotalValue   Price
# 0      300.68  300.68
# 1      300.68  300.68
# 2      300.68  300.68
# 3      601.36  300.68
# 4      902.04  300.68
# 5      300.68  300.68
# 6      902.04  300.68
# 7      300.68  300.68
# ...

# %%
merged=pd.merge(customer,transaction,on="CustomerID",how="inner")
new_merged=pd.merge(merged,product,on=["ProductID","Price"],how="inner")
print(new_merged)
# Out:
#     CustomerID       CustomerName         Region  SignupDate TransactionID  \
# 0        C0001   Lawrence Carroll  South America  2022-07-10        T00015
# 1        C0019  Brandon Rodriguez         Europe  2023-01-12        T00423
# 2        C0038    Jeffrey Perkins  North America  2022-04-16        T00395
# 3        C0039      Angela Harris  South America  2024-10-13        T00053
# 4        C0047     Samantha Frank  North America  2024-03-22        T00784
# ..         ...                ...            ...         ...           ...
# 995      C0125    Nicholas Taylor  North America  2022-12-18        T00266
# 996      C0165      Juan Mcdaniel  South America  2022-04-09        T00672
# 997      C0165      Juan Mcdaniel  South America  2022-04-09        T00711
# 998      C0165      Juan Mcdaniel  South America  2022-04-09        T00878
# 999      C0169      Jennifer Shaw  South America  2023-04-13        T00157
#
#     ProductID      TransactionDate  Quantity  TotalValue   Price  \
# ...

# %%
print(new_merged.describe())
# Out:
#           Quantity   TotalValue       Price
# count  1000.000000  1000.000000  1000.00000
# mean      2.537000   689.995560   272.55407
# std       1.117981   493.144478   140.73639
# min       1.000000    16.080000    16.08000
# 25%       2.000000   295.295000   147.95000
# 50%       3.000000   588.880000   299.93000
# 75%       4.000000  1011.660000   404.40000
# max       4.000000  1991.040000   497.76000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(new_merged)
plt.show()

# %%
print(new_merged['CustomerID'].unique())
# Out:
# ['C0001' 'C0019' 'C0038' 'C0039' 'C0047' 'C0073' 'C0083' 'C0086' 'C0124'
#  'C0143' 'C0156' 'C0165' 'C0171' 'C0181' 'C0190' 'C0025' 'C0035' 'C0065'
#  'C0097' 'C0104' 'C0121' 'C0140' 'C0154' 'C0160' 'C0179' 'C0188' 'C0194'
#  'C0199' 'C0007' 'C0017' 'C0020' 'C0021' 'C0026' 'C0044' 'C0045' 'C0059'
#  'C0075' 'C0117' 'C0119' 'C0161' 'C0164' 'C0016' 'C0023' 'C0046' 'C0051'
 'C0118':118, 'C0119':119, 'C0120':120, 'C0121':121, 'C0122':122, 'C0123':123, 'C0124':124, 'C0125':125, 'C0126':126,
 'C0127':127, 'C0128':128, 'C0129':129, 'C0130':130,'C0131':131, 'C0132':132, 'C0133':133, 'C0134':134, 'C0135':135,
 'C0136':136, 'C0137':137, 'C0138':138, 'C0139':139, 'C0140':140, 'C0141':141, 'C0142':142, 'C0143':143, 'C0144':144,
 'C0145':145, 'C0146':146, 'C0147':147, 'C0148':148, 'C0149':149, 'C0150':150, 'C0151':151, 'C0152':152, 'C0153':153,
 'C0154':154 ,'C0155':155, 'C0156':156, 'C0157':157, 'C0158':158, 'C0159':159, 'C0160':160, 'C0161':161, 'C0162':162,
 'C0163':163, 'C0164':164, 'C0165':165, 'C0166':166, 'C0167':167, 'C0168':168, 'C0169':169, 'C0170':170, 'C0171':171,
 'C0172':172, 'C0173':173, 'C0174':174, 'C0175':175, 'C0176':176, 'C0177':177, 'C0178':178, 'C0179':179, 'C0180':180,
 'C0181':181, 'C0182':182, 'C0183':183, 'C0184':184, 'C0185':185, 'C0186':186, 'C0187':187, 'C0188':188, 'C0189':189,
 'C0190':190, 'C0191':191, 'C0192':192, 'C0193':193, 'C0194':194, 'C0195':195, 'C0196':196, 'C0197':197, 'C0198':198,
 'C0199':199,'C0200':200}

# %%
new_merged['CustomerID'] =new_merged['CustomerID'].map(new_customerID)

# %%
new_merged.head(10)
# Out:
#    CustomerID        CustomerName         Region  SignupDate TransactionID  \
# 0           1    Lawrence Carroll  South America  2022-07-10        T00015
# 1          19   Brandon Rodriguez         Europe  2023-01-12        T00423
# 2          38     Jeffrey Perkins  North America  2022-04-16        T00395
# 3          39       Angela Harris  South America  2024-10-13        T00053
# 4          47      Samantha Frank  North America  2024-03-22        T00784
# 5          73       Heidi Johnson         Europe  2022-08-20        T00634
# 6          83     Christina Stark  South America  2022-04-07        T00581
# 7          86  Stephanie Peterson         Europe  2022-09-18        T00873
# 8         124       Lindsay Perez         Europe  2024-08-26        T00203
# 9         143        Brian Parker           Asia  2024-05-27        T00262
#
#   ProductID      TransactionDate  Quantity  TotalValue  Price  \
# 0      P054  2024-01-19 03:12:55         2       114.6   57.3
# ...

# %%
customer_data = new_merged.groupby('CustomerID').agg({
    'Quantity': 'sum',
    'TotalValue': 'sum',
    'Price': 'mean'
}).reset_index()

# %%
customer_data = customer_data.fillna(0)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
sse = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(customer_data)
    sse.append(kmeans.inertia_)
plt.plot(range(2, 11), sse)
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()
optimal_k = 3  
kmeans = KMeans(n_clusters=optimal_k)
customer_data['Cluster'] = kmeans.fit_predict(customer_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 6
#       4 for k in range(2, 11):
#       5     kmeans = KMeans(n_clusters=k)
# ----> 6     kmeans.fit(customer_data)
#       7     sse.append(kmeans.inertia_)
#       8 plt.plot(range(2, 11), sse)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1519, in KMeans.fit(self, X, y, sample_weight)
#    1517 else:
#    1518     kmeans_single = _kmeans_single_lloyd
# ...

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=new_merged['Quantity'], y=new_merged['Price'])
plt.title('Relationship between Quantity and Price')
plt.xlabel('Quantity')
plt.ylabel('Average Price')
plt.xticks(rotation=90)
plt.show()
